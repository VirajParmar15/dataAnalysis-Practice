# %% [markdown]
# #DATA MANIPULATION

# %%
#create a data frame DSE class
import pandas as pd
dseclass={'Rollno':[101,102,103,104,105],'Name':['Kalyani','Gayatri','Raghav','Kalrav','Seema']}
df=pd.DataFrame(data=dseclass)
df
# Out:
#    Rollno     Name
# 0     101  Kalyani
# 1     102  Gayatri
# 2     103   Raghav
# 3     104   Kalrav
# 4     105    Seema

# %%
#Count Columns in Dataframe
ncol=df.shape[1]
print(ncol)
#Count row in Dataframe
ncol=df.shape[0]
print(ncol)
# Out:
# 2
# 5

# %%
df=pd.read_csv("/content/drive/MyDrive/DATASETS/titanic_gender_survival (1).csv")
df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df.head(25)
# Out:
#     PassengerId  Survived
# 0           892         0
# 1           893         1
# 2           894         0
# 3           895         0
# 4           896         1
# 5           897         0
# 6           898         1
# 7           899         0
# 8           900         1
# 9           901         0
# 10          902         0
# 11          903         0
# 12          904         1
# 13          905         0
# 14          906         1
# 15          907         1
# 16          908         0
# 17          909         0
# 18          910         1
# 19          911         1
# 20          912         0
# 21          913         0
# 22          914         1
# 23          915         0
# 24          916         1

# %%
df.tail(25)
# Out:
#      PassengerId  Survived
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         0
# 405         1297         0
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0

# %%
df_train=pd.read_csv("/content/drive/MyDrive/DATASETS/titanic_test (1).csv")
df_train
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_test=pd.read_csv("/content/drive/MyDrive/DATASETS/titanic_test (1).csv",usecols=["PassengerId","Pclass","Name",'Age'])
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name   Age
# 0          892       3                              Kelly, Mr. James  34.5
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2          894       2                     Myles, Mr. Thomas Francis  62.0
# 3          895       3                              Wirz, Mr. Albert  27.0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age
# count   418.000000  418.000000  332.000000
# mean   1100.500000    2.265550   30.272590
# std     120.810458    0.841838   14.181209
# min     892.000000    1.000000    0.170000
# 25%     996.250000    1.000000   21.000000
# 50%    1100.500000    3.000000   27.000000
# 75%    1204.750000    3.000000   39.000000
# max    1309.000000    3.000000   76.000000

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Age          332 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
df_train.sort_values("Fare")
# Out:
#      PassengerId  Pclass                                               Name  \
# 266         1158       1              Chisholm, Mr. Roderick Robert Crispin
# 372         1264       1                            Ismay, Mr. Joseph Bruce
# 21           913       3                          Olsen, Master. Artur Karl
# 133         1025       3                              Thomas, Mr. Charles P
# 116         1008       3                                   Thomas, Mr. John
# ..           ...     ...                                                ...
# 59           951       1                        Chaudanson, Miss. Victorine
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 152         1044       3                                 Storey, Mr. Thomas
#
# ...

# %%
df_train.sort_values("Fare").head(10)
# Out:
#      PassengerId  Pclass                                    Name     Sex  \
# 266         1158       1   Chisholm, Mr. Roderick Robert Crispin    male
# 372         1264       1                 Ismay, Mr. Joseph Bruce    male
# 21           913       3               Olsen, Master. Artur Karl    male
# 133         1025       3                   Thomas, Mr. Charles P    male
# 116         1008       3                        Thomas, Mr. John    male
# 232         1124       3                 Wiklund, Mr. Karl Johan    male
# 291         1183       3  Daly, Miss. Margaret Marcella Maggie""  female
# 1            893       3        Wilkes, Mrs. James (Ellen Needs)  female
# 163         1055       3                      Pearce, Mr. Ernest    male
# 211         1103       3                       Finoli, Mr. Luigi    male
#
#       Age  SibSp  Parch              Ticket    Fare        Cabin Embarked
# 266   NaN      0      0              112051  0.0000          NaN        S
# ...

# %%
df_train.sort_values("Fare", ascending=False).head(10)
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 59           951       1                        Chaudanson, Miss. Victorine
# 64           956       1                        Ryerson, Master. John Borie
# 375         1267       1                           Bowen, Miss. Grace Scott
# 184         1076       1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 202         1094       1                             Astor, Col. John Jacob
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %%
df_train.sort_values("Fare",ascending=False , inplace=True)
df_train.head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 343  female  58.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 53   female  28.0      3      2     19950  263.0000      C23 C25 C27        S
# 69   female  60.0      1      4     19950  263.0000      C23 C25 C27        S
# 24   female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 142    male  61.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C

# %%
df_train.sort_values("Cabin",ascending=True, na_position='last')
# Out:
#      PassengerId  Pclass                                   Name     Sex   Age  \
# 208         1100       1          Rosenbaum, Miss. Edith Louise  female  33.0
# 331         1223       1           Dulles, Mr. William Crothers    male  39.0
# 28           920       1                Brady, Mr. John Bertram    male  41.0
# 112         1004       1               Evans, Miss. Edith Corse  female  36.0
# 293         1185       1                  Dodge, Dr. Washington    male  53.0
# ..           ...     ...                                    ...     ...   ...
# 116         1008       3                       Thomas, Mr. John    male   NaN
# 133         1025       3                  Thomas, Mr. Charles P    male   NaN
# 21           913       3              Olsen, Master. Artur Karl    male   9.0
# 266         1158       1  Chisholm, Mr. Roderick Robert Crispin    male   NaN
# 152         1044       3                     Storey, Mr. Thomas    male  60.5
#
# ...

# %%
df_train["Sex"].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
df_train.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
df_train["Sex"].nunique()
# Out:
# 2

# %%
df_train["Embarked"].nunique()
# Out:
# 3

# %%
null_mask = df_train["Cabin"].isnull()
dd=df_train[null_mask]
dd
# Out:
#      PassengerId  Pclass                                         Name     Sex  \
# 375         1267       1                     Bowen, Miss. Grace Scott  female
# 324         1216       1                       Kreuchen, Miss. Emilie  female
# 217         1109       1                     Wick, Mr. George Dennick    male
# 141         1033       1                         Daniels, Miss. Sarah  female
# 327         1219       1  Rosenshine, Mr. George (Mr George Thorne")"    male
# ..           ...     ...                                          ...     ...
# 116         1008       3                             Thomas, Mr. John    male
# 133         1025       3                        Thomas, Mr. Charles P    male
# 21           913       3                    Olsen, Master. Artur Karl    male
# 266         1158       1        Chisholm, Mr. Roderick Robert Crispin    male
# 152         1044       3                           Storey, Mr. Thomas    male
#
# ...

# %%
dd.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             82
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dd.drop(labels="Cabin",axis=1).head()
# Out:
#      PassengerId  Pclass                                         Name     Sex  \
# 375         1267       1                     Bowen, Miss. Grace Scott  female
# 324         1216       1                       Kreuchen, Miss. Emilie  female
# 217         1109       1                     Wick, Mr. George Dennick    male
# 141         1033       1                         Daniels, Miss. Sarah  female
# 327         1219       1  Rosenshine, Mr. George (Mr George Thorne")"    male
#
#       Age  SibSp  Parch    Ticket      Fare Embarked
# 375  45.0      0      0  PC 17608  262.3750        C
# 324  39.0      0      0     24160  211.3375        S
# 217  57.0      1      1     36928  164.8667        S
# 141  33.0      0      0    113781  151.5500        S
# 327  46.0      0      0  PC 17585   79.2000        C

# %%
dd.drop(labels=["Cabin","Name"],axis=1).head()
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch    Ticket      Fare  \
# 375         1267       1  female  45.0      0      0  PC 17608  262.3750
# 324         1216       1  female  39.0      0      0     24160  211.3375
# 217         1109       1    male  57.0      1      1     36928  164.8667
# 141         1033       1  female  33.0      0      0    113781  151.5500
# 327         1219       1    male  46.0      0      0  PC 17585   79.2000
#
#     Embarked
# 375        C
# 324        S
# 217        S
# 141        S
# 327        C

# %%
df_train["Age"].fillna("0", inplace = True)
df_train.tail(100)
# Out:
#      PassengerId  Pclass                                   Name     Sex  \
# 357         1249       3                    Lockyer, Mr. Edward    male
# 86           978       3                     Barry, Miss. Julia  female
# 66           958       3                Burns, Miss. Mary Delia  female
# 195         1087       3      Karlsson, Mr. Julius Konrad Eugen    male
# 261         1153       3          Nilsson, Mr. August Ferdinand    male
# ..           ...     ...                                    ...     ...
# 133         1025       3                  Thomas, Mr. Charles P    male
# 21           913       3              Olsen, Master. Artur Karl    male
# 266         1158       1  Chisholm, Mr. Roderick Robert Crispin    male
# 372         1264       1                Ismay, Mr. Joseph Bruce    male
# 152         1044       3                     Storey, Mr. Thomas    male
#
#        Age  SibSp  Parch   Ticket    Fare        Cabin Embarked
# ...
